# %% [markdown]
# # bed-state
#
# > What are the kelp and its community doing on the reef, where, and since when?
#
# 0 sources · 0 references

# %% [markdown]
# ## diver-surveys
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## community
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## invasives
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## mpas
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## General
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## Not held
#
# _No sources._

# %% [markdown]
# ## Reviewed and not included
#
# _Nothing reviewed and not included._

# %% [markdown]
# # canopy
#
# > How has surface canopy extent changed since 1911, bed by bed?
#
# 4 sources · 0 references
#
# | region | aerial-surveys | satellite | historical-baselines | persistence | General |
# | --- | --- | --- | --- | --- | --- |
# | Southern California Bight | 3 | 1 | 2 | 1 | 1 |

# %% [markdown]
# ## aerial-surveys
#
# ### Southern California Bight
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [cdfw_kelp_esr](../../catalog/sources/cdfw_kelp_esr.md) | Giant Kelp and Bull Kelp Enhanced Status Report | California Department of Fish and Wildlife | VERIFIED | FETCHED | The report cites itself as "California Department of Fish and Wildlife. 2021. Giant Kelp and Bull Kelp, Macrocystis pyrifera and Nereocystis luetkeana… | [link](https://marinespecies.wildlife.ca.gov/kelp/) |
# | [sccwrp_kelp_aerial](../../catalog/sources/sccwrp_kelp_aerial.md) | Southern California Bight Regional Aerial Kelp Surveys | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "The status of the giant kelp forests (Macrocystis pyrifera) that occur along most of the southern California coast are mapped annually as part of NPDES… | [link](http://kelp.sccwrp.org/) |
# | [sccwrp_kelp_status_2016](../../catalog/sources/sccwrp_kelp_status_2016.md) | Status of the Kelp Beds in 2016: Ventura, Los Angeles, Orange, and San Diego Counties | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "Aerial surveys were flown on April 18, June 20, September 24, and December 28, 2016."; "The CRKSC program area extends from Ventura Harbor (also referred to… | [link](http://kelp.sccwrp.org/2016/Status_of_the_Kelp_Beds_2016_Ventura_Los%20Angeles_Orange_and_San_Diego_Counties.pdf) |
#
# _No references._

# %% [markdown]
# ## satellite
#
# ### Southern California Bight
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [cdfw_kelp_esr](../../catalog/sources/cdfw_kelp_esr.md) | Giant Kelp and Bull Kelp Enhanced Status Report | California Department of Fish and Wildlife | VERIFIED | FETCHED | The report cites itself as "California Department of Fish and Wildlife. 2021. Giant Kelp and Bull Kelp, Macrocystis pyrifera and Nereocystis luetkeana… | [link](https://marinespecies.wildlife.ca.gov/kelp/) |
#
# _No references._

# %% [markdown]
# ## historical-baselines
#
# ### Southern California Bight
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [sccwrp_b08_rocky_reef](../../catalog/sources/sccwrp_b08_rocky_reef.md) | Southern California Bight 2008 Regional Monitoring Program: Volume V. Rocky Reefs | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "Overall, 72 sites were sampled in the bight"; "60 natural rocky reefs (Figure I-1) from this map were selected using the Generalized Random Tessellation… | [link](https://ftp.sccwrp.org/pub/download/DOCUMENTS/TechnicalReports/685_B08RockyReef.pdf) |
# | [sccwrp_kelp_status_2016](../../catalog/sources/sccwrp_kelp_status_2016.md) | Status of the Kelp Beds in 2016: Ventura, Los Angeles, Orange, and San Diego Counties | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "Aerial surveys were flown on April 18, June 20, September 24, and December 28, 2016."; "The CRKSC program area extends from Ventura Harbor (also referred to… | [link](http://kelp.sccwrp.org/2016/Status_of_the_Kelp_Beds_2016_Ventura_Los%20Angeles_Orange_and_San_Diego_Counties.pdf) |
#
# _No references._

# %% [markdown]
# ## persistence
#
# ### Southern California Bight
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [sccwrp_kelp_status_2016](../../catalog/sources/sccwrp_kelp_status_2016.md) | Status of the Kelp Beds in 2016: Ventura, Los Angeles, Orange, and San Diego Counties | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "Aerial surveys were flown on April 18, June 20, September 24, and December 28, 2016."; "The CRKSC program area extends from Ventura Harbor (also referred to… | [link](http://kelp.sccwrp.org/2016/Status_of_the_Kelp_Beds_2016_Ventura_Los%20Angeles_Orange_and_San_Diego_Counties.pdf) |
#
# _No references._

# %% [markdown]
# ## General
#
# ### Southern California Bight
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [sccwrp_b08_rocky_reef](../../catalog/sources/sccwrp_b08_rocky_reef.md) | Southern California Bight 2008 Regional Monitoring Program: Volume V. Rocky Reefs | Southern California Coastal Water Research Project | VERIFIED | FETCHED | "Overall, 72 sites were sampled in the bight"; "60 natural rocky reefs (Figure I-1) from this map were selected using the Generalized Random Tessellation… | [link](https://ftp.sccwrp.org/pub/download/DOCUMENTS/TechnicalReports/685_B08RockyReef.pdf) |
#
# _No references._

# %% [markdown]
# ## Not held
#
# _No sources._

# %% [markdown]
# ## Reviewed and not included
#
# _Nothing reviewed and not included._

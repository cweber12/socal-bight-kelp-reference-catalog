# %% [markdown]
# # Index
#
# 10 sources · 0 references

# %% [markdown]
# ## physical-environment
#
# ### [ocean-climate](1_physical_environment/11_ocean_climate.ipynb)
#
# 6 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | temperature | 4 | 0 |
# | salinity | 2 | 0 |
# | nutrients | 2 | 0 |
# | upwelling-enso | 2 | 0 |
# | heatwaves | 3 | 0 |
# | oxygen-ph | 2 | 0 |
# | General | 0 | 0 |
#
# ### [canyon-dynamics](1_physical_environment/12_canyon_dynamics.ipynb)
#
# 0 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | internal-tides | 0 | 0 |
# | canyon-circulation | 0 | 0 |
# | observations | 0 | 0 |
# | General | 0 | 0 |
#
# ### [waves-storms-sediment](1_physical_environment/13_waves_storms_sediment.ipynb)
#
# 3 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | swell-climate | 1 | 0 |
# | storms | 1 | 0 |
# | sediment-sand | 1 | 0 |
# | beach-coupling | 0 | 0 |
# | General | 1 | 0 |
#
# ### [substrate](1_physical_environment/14_substrate.ipynb)
#
# 1 source · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | rock-mapping | 1 | 0 |
# | relief-rugosity | 1 | 0 |
# | artificial-substrate | 1 | 0 |
# | General | 0 | 0 |

# %% [markdown]
# ## kelp-and-community
#
# ### [canopy](2_kelp_and_community/21_canopy.ipynb)
#
# 4 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | aerial-surveys | 3 | 0 |
# | satellite | 1 | 0 |
# | historical-baselines | 2 | 0 |
# | persistence | 1 | 0 |
# | General | 1 | 0 |
#
# ### [bed-state](2_kelp_and_community/22_bed_state.ipynb)
#
# 3 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | diver-surveys | 3 | 0 |
# | community | 1 | 0 |
# | invasives | 0 | 0 |
# | mpas | 2 | 0 |
# | General | 1 | 0 |
#
# ### [grazers-predators-competitors](2_kelp_and_community/23_grazers_predators_competitors.ipynb)
#
# 2 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | urchins | 2 | 0 |
# | predators | 0 | 0 |
# | grazing-fishes | 0 | 0 |
# | drift-algae | 0 | 0 |
# | competitors | 0 | 0 |
# | General | 0 | 0 |
#
# ### [recruitment-connectivity](2_kelp_and_community/24_recruitment_connectivity.ipynb)
#
# 0 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | spore-dispersal | 0 | 0 |
# | larval-transport | 0 | 0 |
# | settlement | 0 | 0 |
# | genetics | 0 | 0 |
# | General | 0 | 0 |

# %% [markdown]
# ## human-uses-management
#
# ### [water-quality-harvest](3_human_uses_management/31_water_quality_harvest.ipynb)
#
# 7 sources · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | discharges-outfalls | 4 | 0 |
# | runoff-sedimentation | 1 | 0 |
# | power-plants | 1 | 0 |
# | kelp-harvest | 4 | 0 |
# | fishing-pressure | 1 | 0 |
# | General | 0 | 0 |
#
# ### [restoration-mitigation](3_human_uses_management/32_restoration_mitigation.ipynb)
#
# 1 source · 0 references
#
# | sub-topic | sources | references |
# | --- | --- | --- |
# | outplanting | 1 | 0 |
# | urchin-removal | 1 | 0 |
# | artificial-reefs | 1 | 0 |
# | kelp-farms | 0 | 0 |
# | General | 0 | 0 |

# %% [markdown]
# ## topic × region
#
# | topic | Southern California Bight | No regional bound |
# | --- | --- | --- |
# | ocean-climate | 5 | 1 |
# | canyon-dynamics | 0 | 0 |
# | waves-storms-sediment | 2 | 1 |
# | substrate | 1 | 0 |
# | canopy | 4 | 0 |
# | bed-state | 3 | 0 |
# | grazers-predators-competitors | 2 | 0 |
# | recruitment-connectivity | 0 | 0 |
# | water-quality-harvest | 7 | 0 |
# | restoration-mitigation | 1 | 0 |

# %% [markdown]
# # substrate
#
# > Where is the rock, how complex is it, and what does that predict?
#
# 0 sources · 0 references

# %% [markdown]
# ## rock-mapping
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## relief-rugosity
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## artificial-substrate
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## General
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## Not held
#
# _No sources._

# %% [markdown]
# ## Reviewed and not included
#
# _Nothing reviewed and not included._

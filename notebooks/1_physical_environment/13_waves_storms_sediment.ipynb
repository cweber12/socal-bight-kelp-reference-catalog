# %% [markdown]
# # waves-storms-sediment
#
# > When do swells and storms remove kelp, and what is the sand doing at the bed margins?
#
# 1 source · 0 references
#
# | region | swell-climate | storms | sediment-sand | beach-coupling | General |
# | --- | --- | --- | --- | --- | --- |
# | No regional bound | 0 | 0 | 0 | 0 | 1 |

# %% [markdown]
# ## swell-climate
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## storms
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## sediment-sand
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## beach-coupling
#
# _No sources._
#
# _No references._

# %% [markdown]
# ## General
#
# ### No regional bound
#
# | id | title | steward | status | tier | coverage | link |
# | --- | --- | --- | --- | --- | --- | --- |
# | [noaa_oni](../../catalog/sources/noaa_oni.md) | Oceanic Niño Index | NOAA Climate Prediction Center | VERIFIED | FETCHED | Seasonal ERSSTv6 (centered base periods) "Oceanic Niño Index" or the 3-month running average in Niño 3.4 (5oNorth-5oSouth) (170-120oWest); the data rows of… | [link](https://www.cpc.ncep.noaa.gov/data/indices/oni.ascii.txt) |
#
# _No references._

# %% [markdown]
# ## Not held
#
# _No sources._

# %% [markdown]
# ## Reviewed and not included
#
# _Nothing reviewed and not included._
